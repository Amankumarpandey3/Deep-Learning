# %% [markdown]
# <a href="https://colab.research.google.com/github/Amankumarpandey3/Deep-Learning/blob/main/Data_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img=image.load_img("/content/elephant.jpg",target_size=(250,250))

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
datagen=ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2
)

# %%
img=image.img_to_array(img)

# %%
img.shape
# Out:
# (250, 250, 3)

# %%
input_batch=img.reshape(1,250,250,3)

# %%
i=0
for output in datagen.flow(input_batch,batch_size=1,save_to_dir='aug'):
  i=i+1
  if i==10:
    break
