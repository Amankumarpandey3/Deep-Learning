# %% [markdown]
# <a href="https://colab.research.google.com/github/Amankumarpandey3/Deep-Learning/blob/main/Perceptron_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sameerprogrammer/college-placement")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 741/741 [00:00<00:00, 1.53MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/sameerprogrammer/college-placement/versions/1

# %%
import os

file_name = "placement-dataset.csv"
file_path = os.path.join(path, file_name)

df=pd.read_csv(file_path)

# %%
import os

# List files in the downloaded directory
file_list = os.listdir(path)
print(file_list)
# Out:
# ['placement-dataset.csv']

# %%
print(df.shape)
# Out:
# (100, 4)

# %%
sns.scatterplot(x='iq', y='cgpa', hue='placement', data=df)
# Out:
# <Axes: xlabel='iq', ylabel='cgpa'>

# %%
X=df[['iq','cgpa']]
Y=df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p=Perceptron()

# %%
p.fit(X,Y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[11., 47.]])

# %%
p.intercept_
# Out:
# array([-72.])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, Y.values, clf=p, legend=2)
plt.xlabel('iq')
plt.ylabel('cgpa')
plt.title('Perceptron Decision Boundary')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
